# %% [markdown]
# 各位同学，大家好!  欢迎各位开始学习我们的人工智能课程。
# 这门课程假设大家不具备机器学习和人工智能的知识，但是希望大家具备初级的Python编程能力。
# 这门课程结束后，希望大家掌握Python语言以及人工智能基础知识，对CV，NLP，RS领域有一定深入的理解与编程能力。

# %% [markdown]
# # 本次作业要求

# %% [markdown]
# ## 作业形式

# %% [markdown]
# 复现课程代码
# 完成课后作业

# %% [markdown]
# ## 作业提交方式

# %% [markdown]
# 完成填写此`jupyter`文件，提交至自己的github，或通过KKB作业平台提交附件

# %% [markdown]
# ## 作业截止时间

# %% [markdown]
# 每次课程作业都会在下次课程(2019年11月15日)进行讲解，最好在一周内尽快提交。
# 此次作业批改截止时间：2019年11月22日

# %% [markdown]
# # 完成以下问答和编程练习

# %% [markdown]
# **理论部分**
# 无

# %% [markdown]
# **编程实践部分**

# %% [markdown]
# 1. 数据集保存及读取
# 添加编号列，并将数据集写入到`machine_learning.csv`文件，使用pandas读取验证文件是否有效(无错即可)。
# 添加一条记录，`青绿 硬挺 浊响 稍糊 平坦 硬滑 0.666 0.111 好`
# 再使用普通文件读取将数据集读取出来，列名读取到`columns`，数据(带编号)读取到`datalist`
# 在所有数据中过滤出色泽='浅白'的数据
# 在所有数据中过滤出密度大于0.5的数据

# %% [markdown]
# 2.无

# %%
import pandas as pd
import re

dataset = \
"""色泽 根蒂 敲声 纹理 脐部 触感 密度 含糖率 好瓜
青绿 蜷缩 浊响 清晰 凹陷 硬滑 0.697 0.460 是
乌黑 蜷缩 沉闷 清晰 凹陷 硬滑 0.774 0.376 是
乌黑 蜷缩 浊响 清晰 凹陷 硬滑 0.634 0.264 是
青绿 蜷缩 沉闷 清晰 凹陷 硬滑 0.608 0.318 是
浅白 蜷缩 浊响 清晰 凹陷 硬滑 0.556 0.215 是
青绿 稍蜷 浊响 清晰 稍凹 软粘 0.403 0.237 是
乌黑 稍蜷 浊响 稍糊 稍凹 软粘 0.481 0.149 是
乌黑 稍蜷 浊响 清晰 稍凹 硬滑 0.437 0.211 是
乌黑 稍蜷 沉闷 稍糊 稍凹 硬滑 0.666 0.091 否
青绿 硬挺 清脆 清晰 平坦 软粘 0.243 0.267 否
浅白 硬挺 清脆 模糊 平坦 硬滑 0.245 0.057 否
浅白 蜷缩 浊响 模糊 平坦 软粘 0.343 0.099 否
青绿 稍蜷 浊响 稍糊 凹陷 硬滑 0.639 0.161 否
浅白 稍蜷 沉闷 稍糊 凹陷 硬滑 0.657 0.198 否
乌黑 稍蜷 浊响 清晰 稍凹 软粘 0.360 0.370 否
浅白 蜷缩 浊响 模糊 平坦 硬滑 0.593 0.042 否
青绿 蜷缩 沉闷 稍糊 稍凹 硬滑 0.719 0.103 否"""
# file path, you can change the direction
file = r'machine_learning.csv' 
with open(file,'w',encoding='utf-8') as f:
    dataset = dataset.replace(' ',',')#replace的用法 
    #print(dataset)
    #print(type(dataset)) 此时的字符串仍为字符串
    
    
    dataset = dataset.split('\n')#\n 依回车隔开，转换成列表
    #print(dataset)
    #print(type(dataset)) 数据类型为list
    
    lens = len(dataset)
   
    ###重点
    #添加编号和索引
    f.write('编号,'+dataset[0]+'\n')
    for i in range(1, lens):
        f.write(str(i) + ',' + dataset[i] + '\n')
        
        
#添加一条新数据
with open(file,'a',encoding='utf-8') as f:
    f.write('18 青绿 硬挺 浊响 稍糊 平坦 硬滑 0.666 0.111 好'.replace(' ', ','))   
    
#打印第一列
txt = open(file, encoding='utf-8').readlines()
columns = txt[0]

#打印数据
datalist = []
with open(file,encoding='utf-8') as f:
    for line in f.readlines():
        data = line.strip().split(',')
        datalist.append(data)



print(" 色泽='浅白'的数据是", list(filter(lambda x:x[1]=='浅白', datalist)))
print()

del datalist[0] #没有删除第一行导致float无法将第一行的‘密度’转为float类型 出现错误
print('密度大于0.5的数据是', list(filter(lambda x:float(x[7])>0.5, datalist)))

print()
print('columns = ', columns)        
print('datalist =', datalist)
print()


 ##总结 作业部分参考老师 
 ###前几节课的学的函数快忘光了，还有一些函数的隐含意义例如**split()**可以以字符产中某种的符号，空格，回车等分割成列表(分割，和转换)
##filter和lambda的用法十分强大
# Out:
#  色泽='浅白'的数据是 [['5', '浅白', '蜷缩', '浊响', '清晰', '凹陷', '硬滑', '0.556', '0.215', '是'], ['11', '浅白', '硬挺', '清脆', '模糊', '平坦', '硬滑', '0.245', '0.057', '否'], ['12', '浅白', '蜷缩', '浊响', '模糊', '平坦', '软粘', '0.343', '0.099', '否'], ['14', '浅白', '稍蜷', '沉闷', '稍糊', '凹陷', '硬滑', '0.657', '0.198', '否'], ['16', '浅白', '蜷缩', '浊响', '模糊', '平坦', '硬滑', '0.593', '0.042', '否']]
#
# 密度大于0.5的数据是 [['1', '青绿', '蜷缩', '浊响', '清晰', '凹陷', '硬滑', '0.697', '0.460', '是'], ['2', '乌黑', '蜷缩', '沉闷', '清晰', '凹陷', '硬滑', '0.774', '0.376', '是'], ['3', '乌黑', '蜷缩', '浊响', '清晰', '凹陷', '硬滑', '0.634', '0.264', '是'], ['4', '青绿', '蜷缩', '沉闷', '清晰', '凹陷', '硬滑', '0.608', '0.318', '是'], ['5', '浅白', '蜷缩', '浊响', '清晰', '凹陷', '硬滑', '0.556', '0.215', '是'], ['9', '乌黑', '稍蜷', '沉闷', '稍糊', '稍凹', '硬滑', '0.666', '0.091', '否'], ['13', '青绿', '稍蜷', '浊响', '稍糊', '凹陷', '硬滑', '0.639', '0.161', '否'], ['14', '浅白', '稍蜷', '沉闷', '稍糊', '凹陷', '硬滑', '0.657', '0.198', '否'], ['16', '浅白', '蜷缩', '浊响', '模糊', '平坦', '硬滑', '0.593', '0.042', '否'], ['17', '青绿', '蜷缩', '沉闷', '稍糊', '稍凹', '硬滑', '0.719', '0.103', '否'], ['18', '青绿', '硬挺', '浊响', '稍糊', '平坦', '硬滑', '0.666', '0.111', '好']]
#
# columns =  编号,色泽,根蒂,敲声,纹理,脐部,触感,密度,含糖率,好瓜
#
# datalist = [['1', '青绿', '蜷缩', '浊响', '清晰', '凹陷', '硬滑', '0.697', '0.460', '是'], ['2', '乌黑', '蜷缩', '沉闷', '清晰', '凹陷', '硬滑', '0.774', '0.376', '是'], ['3', '乌黑', '蜷缩', '浊响', '清晰', '凹陷', '硬滑', '0.634', '0.264', '是'], ['4', '青绿', '蜷缩', '沉闷', '清晰', '凹陷', '硬滑', '0.608', '0.318', '是'], ['5', '浅白', '蜷缩', '浊响', '清晰', '凹陷', '硬滑', '0.556', '0.215', '是'], ['6', '青绿', '稍蜷', '浊响', '清晰', '稍凹', '软粘', '0.403', '0.237', '是'], ['7', '乌黑', '稍蜷', '浊响', '稍糊', '稍凹', '软粘', '0.481', '0.149', '是'], ['8', '乌黑', '稍蜷', '浊响', '清晰', '稍凹', '硬滑', '0.437', '0.211', '是'], ['9', '乌黑', '稍蜷', '沉闷', '稍糊', '稍凹', '硬滑', '0.666', '0.091', '否'], ['10', '青绿', '硬挺', '清脆', '清晰', '平坦', '软粘', '0.243', '0.267', '否'], ['11', '浅白', '硬挺', '清脆', '模糊', '平坦', '硬滑', '0.245', '0.057', '否'], ['12', '浅白', '蜷缩', '浊响', '模糊', '平坦', '软粘', '0.343', '0.099', '否'], ['13', '青绿', '稍蜷', '浊响', '稍糊', '凹陷', '硬滑', '0.639', '0.161', '否'], ['14', '浅白', '稍蜷', '沉闷', '稍糊', '凹陷', '硬滑', '0.657', '0.198', '否'], ['15', '乌黑', '稍蜷', '浊响', '清晰', '稍凹', '软粘', '0.360', '0.370', '否'], ['16', '浅白', '蜷缩', '浊响', '模糊', '平坦', '硬滑', '0.593', '0.042', '否'], ['17', '青绿', '蜷缩', '沉闷', '稍糊', '稍凹', '硬滑', '0.719', '0.103', '否'], ['18', '青绿', '硬挺', '浊响', '稍糊', '平坦', '硬滑', '0.666', '0.111', '好']]
